# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("students.csv")

# %%
print(df.head())
# Out:
#      Name  Math  Science  English  Hours_Studied  Attendance
# 0    Aman    78       85       82              4          85
# 1    Riya    92       88       91              6          95
# 2     Raj    65       70       68              3          75
# 3  Simran    88       90       85              5          90
# 4   Karan    55       60       58              2          70

# %%
# UNIVARIATE ANALYSIS

# Basic statistics
print("\nStatistical Summary:")
print(df.describe())

# Histogram - Math marks
plt.hist(df['Math'], bins=5)
plt.title("Distribution of Math Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# Boxplot - Science marks
sns.boxplot(y=df['Science'])
plt.title("Boxplot of Science Marks")
plt.show()
# Out:
# Statistical Summary:
#             Math    Science    English  Hours_Studied  Attendance
# count  10.000000  10.000000  10.000000       10.00000   10.000000
# mean   77.000000  80.000000  78.600000        4.10000   84.500000
# std    13.686977  11.234866  12.112436        1.66333    9.823441
# min    55.000000  60.000000  58.000000        2.00000   70.000000
# 25%    66.750000  72.000000  69.750000        3.00000   76.250000
# 50%    79.000000  85.000000  83.000000        4.00000   86.500000
# 75%    87.250000  87.750000  85.750000        5.00000   91.500000
# max    95.000000  92.000000  94.000000        7.00000   98.000000

# %%
#  BIVARIATE ANALYSIS


# Scatter plot - Hours vs Math
plt.scatter(df['Hours_Studied'], df['Math'])
plt.title("Hours Studied vs Math Marks")
plt.xlabel("Hours Studied")
plt.ylabel("Math Marks")
plt.show()

# Correlation matrix
corr = df.corr(numeric_only=True)
print("\nCorrelation Matrix:")
print(corr)

# Heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                    Math   Science   English  Hours_Studied  Attendance
# Math           1.000000  0.973307  0.989247       0.966355    0.991671
# Science        0.973307  1.000000  0.982254       0.897818    0.961456
# English        0.989247  0.982254  1.000000       0.945275    0.989847
# Hours_Studied  0.966355  0.897818  0.945275       1.000000    0.969015
# Attendance     0.991671  0.961456  0.989847       0.969015    1.000000
